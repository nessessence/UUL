# %%
import torch

# %%
coco_cache = torch.load("data_root/cache/mace/cache_coco.pt")
# Out:
# {'0_for_mat1': tensor([[  7351429.5000,  -2800283.0000,  -2178781.5000,  ...,
#             5863744.5000,   6029714.0000,   6335689.5000],
#          [-13663771.0000,  -7013261.0000,   2548152.2500,  ...,
#            13082382.0000,  -2528606.5000,  -3756339.2500],
#          [ -9262724.0000,   4154244.0000,    165196.7500,  ...,
#           -12624241.0000,   -337983.6250,  -1194081.2500],
#          ...,
#          [ -2815495.0000,   5160445.5000,  -3453477.0000,  ...,
#            -4701840.5000,  -1185182.0000,   -225687.6562],
#          [  2151122.5000,  -6636705.0000,   1698255.5000,  ...,
#             6509365.0000,   2498432.5000,    657743.1875],
#          [   379969.4062,  -2562950.7500,    767053.6250,  ...,
#             3543517.2500,    -86378.1484,   -518544.4375]], device='cuda:0'),
#  '0_for_mat2': tensor([[ 48751208.0000,    527708.1250,  -4376768.5000,  ...,
#              109665.0781,   1243191.3750,   2559208.2500],
# ...

# %%
hippo_cache = torch.load('data_root/cache/mace/general_concept/cache_hippo.pt')
