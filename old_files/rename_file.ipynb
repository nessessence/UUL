# %%
import os
# file_names = ['esd-Barrack_Obama-from-Barrack_Obama-esdx_nG3.00_BGeneral', 'esd-Rihanna-from-Rihanna-esdx_nG3.00_BGeneral', 'esd-Ed_Sheeran-from-Ed_Sheeran-esdx_nG3.00_BGeneral', 'esd-Margot_Robbie-from-Margot_Robbie-esdx_nG3.00_BGeneral', 'esd-Chris_Hemsworth-from-Chris_Hemsworth-esdx_nG3.00_BGeneral', 'esd-Chris_Evans-from-Chris_Evans-esdx_nG3.00_BGeneral', 'esd-Amy_Adams-from-Amy_Adams-esdx_nG3.00_BGeneral', 'esd-Anne_Hathaway-from-Anne_Hathaway-esdx_nG3.00_BGeneral', 'esd-Mariah_Carey-from-Mariah_Carey-esdx_nG3.00_BGeneral', 'esd-Octavia_Spencer-from-Octavia_Spencer-esdx_nG3.00_BGeneral', 'esd-Morgan_Freeman-from-Morgan_Freeman-esdx_nG3.00_BGeneral', 'esd-Drake-from-Drake-esdx_nG3.00_BGeneral']
# file_names += ['esd-Barrack_Obama-from-Barrack_Obama-esdx_nG1.00_BGeneral', 'esd-Rihanna-from-Rihanna-esdx_nG1.00_BGeneral', 'esd-Ed_Sheeran-from-Ed_Sheeran-esdx_nG1.00_BGeneral', 'esd-Margot_Robbie-from-Margot_Robbie-esdx_nG1.00_BGeneral', 'esd-Chris_Hemsworth-from-Chris_Hemsworth-esdx_nG1.00_BGeneral', 'esd-Chris_Evans-from-Chris_Evans-esdx_nG1.00_BGeneral', 'esd-Amy_Adams-from-Amy_Adams-esdx_nG1.00_BGeneral', 'esd-Anne_Hathaway-from-Anne_Hathaway-esdx_nG1.00_BGeneral', 'esd-Mariah_Carey-from-Mariah_Carey-esdx_nG1.00_BGeneral', 'esd-Octavia_Spencer-from-Octavia_Spencer-esdx_nG1.00_BGeneral', 'esd-Morgan_Freeman-from-Morgan_Freeman-esdx_nG1.00_BGeneral', 'esd-Drake-from-Drake-esdx_nG1.00_BGeneral']
# file_names = ['esd-Barrack_Obama-from-Barrack_Obama-esdx_PS0.25_BGeneral', 'esd-Rihanna-from-Rihanna-esdx_PS0.25_BGeneral', 'esd-Ed_Sheeran-from-Ed_Sheeran-esdx_PS0.25_BGeneral', 'esd-Margot_Robbie-from-Margot_Robbie-esdx_PS0.25_BGeneral', 'esd-Chris_Hemsworth-from-Chris_Hemsworth-esdx_PS0.25_BGeneral', 'esd-Chris_Evans-from-Chris_Evans-esdx_PS0.25_BGeneral', 'esd-Amy_Adams-from-Amy_Adams-esdx_PS0.25_BGeneral', 'esd-Anne_Hathaway-from-Anne_Hathaway-esdx_PS0.25_BGeneral', 'esd-Mariah_Carey-from-Mariah_Carey-esdx_PS0.25_BGeneral', 'esd-Octavia_Spencer-from-Octavia_Spencer-esdx_PS0.25_BGeneral', 'esd-Morgan_Freeman-from-Morgan_Freeman-esdx_PS0.25_BGeneral', 'esd-Drake-from-Drake-esdx_PS0.25_BGeneral']
# file_names = ['esd-Barrack_Obama-from-Barrack_Obama-esdx_nG1.00_PS1.00_BGeneral', 'esd-Rihanna-from-Rihanna-esdx_nG1.00_PS1.00_BGeneral', 'esd-Ed_Sheeran-from-Ed_Sheeran-esdx_nG1.00_PS1.00_BGeneral', 'esd-Margot_Robbie-from-Margot_Robbie-esdx_nG1.00_PS1.00_BGeneral', 'esd-Chris_Hemsworth-from-Chris_Hemsworth-esdx_nG1.00_PS1.00_BGeneral', 'esd-Chris_Evans-from-Chris_Evans-esdx_nG1.00_PS1.00_BGeneral', 'esd-Amy_Adams-from-Amy_Adams-esdx_nG1.00_PS1.00_BGeneral', 'esd-Anne_Hathaway-from-Anne_Hathaway-esdx_nG1.00_PS1.00_BGeneral', 'esd-Mariah_Carey-from-Mariah_Carey-esdx_nG1.00_PS1.00_BGeneral', 'esd-Octavia_Spencer-from-Octavia_Spencer-esdx_nG1.00_PS1.00_BGeneral', 'esd-Morgan_Freeman-from-Morgan_Freeman-esdx_nG1.00_PS1.00_BGeneral', 'esd-Drake-from-Drake-esdx_nG1.00_PS1.00_BGeneral']
file_names = ['esd-Barrack_Obama-from-Barrack_Obama-esdx_PS1.00_BGeneral', 'esd-Rihanna-from-Rihanna-esdx_PS1.00_BGeneral', 'esd-Ed_Sheeran-from-Ed_Sheeran-esdx_PS1.00_BGeneral', 'esd-Margot_Robbie-from-Margot_Robbie-esdx_PS1.00_BGeneral', 'esd-Chris_Hemsworth-from-Chris_Hemsworth-esdx_PS1.00_BGeneral', 'esd-Chris_Evans-from-Chris_Evans-esdx_PS1.00_BGeneral', 'esd-Amy_Adams-from-Amy_Adams-esdx_PS1.00_BGeneral', 'esd-Anne_Hathaway-from-Anne_Hathaway-esdx_PS1.00_BGeneral', 'esd-Mariah_Carey-from-Mariah_Carey-esdx_PS1.00_BGeneral', 'esd-Octavia_Spencer-from-Octavia_Spencer-esdx_PS1.00_BGeneral', 'esd-Morgan_Freeman-from-Morgan_Freeman-esdx_PS1.00_BGeneral', 'esd-Drake-from-Drake-esdx_PS1.00_BGeneral']
file_names = ['esd-Barrack_Obama-from-Barrack_Obama-esdx_nG3.00_PS1.00_BGeneral', 'esd-Rihanna-from-Rihanna-esdx_nG3.00_PS1.00_BGeneral', 'esd-Ed_Sheeran-from-Ed_Sheeran-esdx_nG3.00_PS1.00_BGeneral', 'esd-Margot_Robbie-from-Margot_Robbie-esdx_nG3.00_PS1.00_BGeneral', 'esd-Chris_Hemsworth-from-Chris_Hemsworth-esdx_nG3.00_PS1.00_BGeneral', 'esd-Chris_Evans-from-Chris_Evans-esdx_nG3.00_PS1.00_BGeneral', 'esd-Amy_Adams-from-Amy_Adams-esdx_nG3.00_PS1.00_BGeneral', 'esd-Anne_Hathaway-from-Anne_Hathaway-esdx_nG3.00_PS1.00_BGeneral', 'esd-Mariah_Carey-from-Mariah_Carey-esdx_nG3.00_PS1.00_BGeneral', 'esd-Octavia_Spencer-from-Octavia_Spencer-esdx_nG3.00_PS1.00_BGeneral', 'esd-Morgan_Freeman-from-Morgan_Freeman-esdx_nG3.00_PS1.00_BGeneral', 'esd-Drake-from-Drake-esdx_nG3.00_PS1.00_BGeneral']
file_names = ['esd-Barrack_Obama-from-Barrack_Obama-esdx_nG2.50_BGeneral', 'esd-Rihanna-from-Rihanna-esdx_nG2.50_BGeneral', 'esd-Ed_Sheeran-from-Ed_Sheeran-esdx_nG2.50_BGeneral', 'esd-Margot_Robbie-from-Margot_Robbie-esdx_nG2.50_BGeneral', 'esd-Chris_Hemsworth-from-Chris_Hemsworth-esdx_nG2.50_BGeneral', 'esd-Chris_Evans-from-Chris_Evans-esdx_nG2.50_BGeneral', 'esd-Amy_Adams-from-Amy_Adams-esdx_nG2.50_BGeneral', 'esd-Anne_Hathaway-from-Anne_Hathaway-esdx_nG2.50_BGeneral', 'esd-Mariah_Carey-from-Mariah_Carey-esdx_nG2.50_BGeneral', 'esd-Octavia_Spencer-from-Octavia_Spencer-esdx_nG2.50_BGeneral', 'esd-Morgan_Freeman-from-Morgan_Freeman-esdx_nG2.50_BGeneral', 'esd-Drake-from-Drake-esdx_nG2.50_BGeneral']

file_names += [ f"{fname}.safetensors" for fname in file_names ]

target_file_names = list(file_names)
file_names = [ fname.replace("nG2.50","nG2.5") for fname in target_file_names ]

root_dir = "data_root/logs/esd/sd1.4/"

for fname, target_fname in zip(file_names, target_file_names):
    src = os.path.join(root_dir, fname)
    dst = os.path.join(root_dir, target_fname)
    if os.path.exists(src):
        print(f"Renaming {fname} to {target_fname}")
        # os.rename(src, dst)
# Out:
# Renaming esd-Barrack_Obama-from-Barrack_Obama-esdx_nG2.5_BGeneral.safetensors to esd-Barrack_Obama-from-Barrack_Obama-esdx_nG2.50_BGeneral.safetensors
# Renaming esd-Rihanna-from-Rihanna-esdx_nG2.5_BGeneral.safetensors to esd-Rihanna-from-Rihanna-esdx_nG2.50_BGeneral.safetensors
# Renaming esd-Ed_Sheeran-from-Ed_Sheeran-esdx_nG2.5_BGeneral.safetensors to esd-Ed_Sheeran-from-Ed_Sheeran-esdx_nG2.50_BGeneral.safetensors
# Renaming esd-Margot_Robbie-from-Margot_Robbie-esdx_nG2.5_BGeneral.safetensors to esd-Margot_Robbie-from-Margot_Robbie-esdx_nG2.50_BGeneral.safetensors
# Renaming esd-Chris_Hemsworth-from-Chris_Hemsworth-esdx_nG2.5_BGeneral.safetensors to esd-Chris_Hemsworth-from-Chris_Hemsworth-esdx_nG2.50_BGeneral.safetensors
# Renaming esd-Chris_Evans-from-Chris_Evans-esdx_nG2.5_BGeneral.safetensors to esd-Chris_Evans-from-Chris_Evans-esdx_nG2.50_BGeneral.safetensors
# ...
