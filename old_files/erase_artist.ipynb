# %% [markdown]
# ### 1. Generate images with the original model

# %%
import torch
from diffusers import StableDiffusionPipeline

model_id = "CompVis/stable-diffusion-v1-4"
device = "cuda"

pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to(device)
pipe.safety_checker = None
pipe.requires_safety_checker = False
torch.Generator(device=device).manual_seed(40)
    
prompt = "a photo of Amy Adams"

image = pipe(prompt).images[0]  
    
display(image)

del pipe
torch.cuda.empty_cache()
# Out:
# /home/nessessence/anaconda3/envs/mace/lib/python3.10/site-packages/torchvision/datapoints/__init__.py:12: UserWarning: The torchvision.datapoints and torchvision.transforms.v2 namespaces are still Beta. While we do not expect major breaking changes, some APIs may still change according to user feedback. Please submit any feedback you may have in this issue: https://github.com/pytorch/vision/issues/6753, and you can also check out https://github.com/pytorch/vision/issues/7319 to learn more about the APIs that we suspect might involve future changes. You can silence this warning by calling torchvision.disable_beta_transforms_warning().
#   warnings.warn(_BETA_TRANSFORMS_WARNING)
# /home/nessessence/anaconda3/envs/mace/lib/python3.10/site-packages/torchvision/transforms/v2/__init__.py:54: UserWarning: The torchvision.datapoints and torchvision.transforms.v2 namespaces are still Beta. While we do not expect major breaking changes, some APIs may still change according to user feedback. Please submit any feedback you may have in this issue: https://github.com/pytorch/vision/issues/6753, and you can also check out https://github.com/pytorch/vision/issues/7319 to learn more about the APIs that we suspect might involve future changes. You can silence this warning by calling torchvision.disable_beta_transforms_warning().
#   warnings.warn(_BETA_TRANSFORMS_WARNING)
# /home/nessessence/anaconda3/envs/mace/lib/python3.10/site-packages/huggingface_hub/file_download.py:1142: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
import torch
from diffusers import StableDiffusionPipeline

model_id = "CompVis/stable-diffusion-v1-4"
device = "cuda"

pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to(device)
pipe.safety_checker = None
pipe.requires_safety_checker = False
torch.Generator(device=device).manual_seed(41)
    
prompt = "a photo of Amy Adams"

image = pipe(prompt).images[0]  
    
display(image)

del pipe
torch.cuda.empty_cache()
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
import torch
from diffusers import StableDiffusionPipeline

model_id = "CompVis/stable-diffusion-v1-4"
device = "cuda"

pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to(device)
pipe.safety_checker = None
pipe.requires_safety_checker = False
torch.Generator(device=device).manual_seed(40)
    
prompt = "a photo of Adriana Lima"

image = pipe(prompt).images[0]  
    
display(image)

del pipe
torch.cuda.empty_cache()
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
import torch
from diffusers import StableDiffusionPipeline

model_id = "CompVis/stable-diffusion-v1-4"
device = "cuda"

pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to(device)
pipe.safety_checker = None
pipe.requires_safety_checker = False
torch.Generator(device=device).manual_seed(0)
    
prompt = "a photo of Adriana Lima"

image = pipe(prompt).images[0]  
    
display(image)

del pipe
torch.cuda.empty_cache()
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
import torch
from diffusers import StableDiffusionPipeline

model_id = "CompVis/stable-diffusion-v1-4"
device = "cuda"

pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to(device)
pipe.safety_checker = None
pipe.requires_safety_checker = False
torch.Generator(device=device).manual_seed(42)
    
prompt = "a photo of Amber Heard"

image = pipe(prompt).images[0]  
    
display(image)

del pipe
torch.cuda.empty_cache()
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
import torch
from diffusers import StableDiffusionPipeline

model_id = "CompVis/stable-diffusion-v1-4"
device = "cuda"

pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to(device)
pipe.safety_checker = None
pipe.requires_safety_checker = False
torch.Generator(device=device).manual_seed(42)
    
prompt = "Bouquet of Sunflowers by Claude Monet"

image = pipe(prompt).images[0]  
    
display(image)

del pipe
torch.cuda.empty_cache()
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
import torch
from diffusers import StableDiffusionPipeline

model_id = "CompVis/stable-diffusion-v1-4"
device = "cuda"

pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to(device)
pipe.safety_checker = None
pipe.requires_safety_checker = False
torch.Generator(device=device).manual_seed(42)
    
prompt = "An artwork by Claude Monet"

image = pipe(prompt).images[0]  
    
display(image)

del pipe
torch.cuda.empty_cache()
# Out:
# /home/nessessence/anaconda3/envs/mace/lib/python3.10/site-packages/torchvision/datapoints/__init__.py:12: UserWarning: The torchvision.datapoints and torchvision.transforms.v2 namespaces are still Beta. While we do not expect major breaking changes, some APIs may still change according to user feedback. Please submit any feedback you may have in this issue: https://github.com/pytorch/vision/issues/6753, and you can also check out https://github.com/pytorch/vision/issues/7319 to learn more about the APIs that we suspect might involve future changes. You can silence this warning by calling torchvision.disable_beta_transforms_warning().
#   warnings.warn(_BETA_TRANSFORMS_WARNING)
# /home/nessessence/anaconda3/envs/mace/lib/python3.10/site-packages/torchvision/transforms/v2/__init__.py:54: UserWarning: The torchvision.datapoints and torchvision.transforms.v2 namespaces are still Beta. While we do not expect major breaking changes, some APIs may still change according to user feedback. Please submit any feedback you may have in this issue: https://github.com/pytorch/vision/issues/6753, and you can also check out https://github.com/pytorch/vision/issues/7319 to learn more about the APIs that we suspect might involve future changes. You can silence this warning by calling torchvision.disable_beta_transforms_warning().
#   warnings.warn(_BETA_TRANSFORMS_WARNING)
# /home/nessessence/anaconda3/envs/mace/lib/python3.10/site-packages/huggingface_hub/file_download.py:1142: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# ### 2. Data preparation for finetuning

# %%
import subprocess, os
config_path = "configs/celebrity/erase_cele_5.yaml"
config_path = "configs/celebrity/erase_cele_5.yaml"
cuda_num = 0

subprocess.run(
    ["python", "data_preparation.py", config_path],
    env={"CUDA_VISIBLE_DEVICES": str(cuda_num), **dict(**os.environ)}
)
# Out:
# /home/nessessence/anaconda3/envs/mace/lib/python3.10/site-packages/torchvision/datapoints/__init__.py:12: UserWarning: The torchvision.datapoints and torchvision.transforms.v2 namespaces are still Beta. While we do not expect major breaking changes, some APIs may still change according to user feedback. Please submit any feedback you may have in this issue: https://github.com/pytorch/vision/issues/6753, and you can also check out https://github.com/pytorch/vision/issues/7319 to learn more about the APIs that we suspect might involve future changes. You can silence this warning by calling torchvision.disable_beta_transforms_warning().
#   warnings.warn(_BETA_TRANSFORMS_WARNING)
# /home/nessessence/anaconda3/envs/mace/lib/python3.10/site-packages/torchvision/transforms/v2/__init__.py:54: UserWarning: The torchvision.datapoints and torchvision.transforms.v2 namespaces are still Beta. While we do not expect major breaking changes, some APIs may still change according to user feedback. Please submit any feedback you may have in this issue: https://github.com/pytorch/vision/issues/6753, and you can also check out https://github.com/pytorch/vision/issues/7319 to learn more about the APIs that we suspect might involve future changes. You can silence this warning by calling torchvision.disable_beta_transforms_warning().
#   warnings.warn(_BETA_TRANSFORMS_WARNING)
# /home/nessessence/anaconda3/envs/mace/lib/python3.10/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /home/nessessence/anaconda3/envs/mace/lib/python3.10/site-packages/huggingface_hub/file_download.py:1142: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loading pipeline components...: 100%|██████████| 7/7 [00:00<00:00,  9.08it/s]
# Generating training data for concept 1: adam-driver...
# Inferencing: a photo of the adam driver
# 100%|██████████| 30/30 [00:24<00:00,  1.23it/s]
# Generating training data for concept 2: adriana-lima...
# Inferencing: a photo of the adriana lima
# 100%|██████████| 30/30 [00:24<00:00,  1.24it/s]
# Generating training data for concept 3: amber-heard...
# Inferencing: a photo of the amber heard
# 100%|██████████| 30/30 [00:24<00:00,  1.24it/s]
# Generating training data for concept 4: amy-adams...
# Inferencing: a photo of the amy adams
# 100%|██████████| 30/30 [00:24<00:00,  1.24it/s]
# Generating training data for concept 5: andrew-garfield...
# Inferencing: a photo of the andrew garfield
# 100%|██████████| 30/30 [00:24<00:00,  1.24it/s]
# /home/nessessence/anaconda3/envs/mace/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /opt/conda/conda-bld/pytorch_1682343967769/work/aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /home/nessessence/anaconda3/envs/mace/lib/python3.10/site-packages/transformers/modeling_utils.py:1161: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /home/nessessence/anaconda3/envs/mace/lib/python3.10/site-packages/torch/utils/checkpoint.py:31: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn("None of the inputs have requires_grad=True. Gradients will be None")
# final text_encoder_type: bert-base-uncased
# _IncompatibleKeys(missing_keys=[], unexpected_keys=['label_enc.weight', 'bert.embeddings.position_ids'])
# <All keys matched successfully>
# ./data/5cele/adriana lima mask/a-photo-of-the-adriana-lima_0_mask.jpg
# ./data/5cele/adriana lima mask/a-photo-of-the-adriana-lima_7_mask.jpg
# ./data/5cele/adriana lima mask/a-photo-of-the-adriana-lima_4_mask.jpg
# ./data/5cele/adriana lima mask/a-photo-of-the-adriana-lima_2_mask.jpg
# ./data/5cele/adriana lima mask/a-photo-of-the-adriana-lima_6_mask.jpg
# ./data/5cele/adriana lima mask/a-photo-of-the-adriana-lima_3_mask.jpg
# ./data/5cele/adriana lima mask/a-photo-of-the-adriana-lima_1_mask.jpg
# ./data/5cele/adriana lima mask/a-photo-of-the-adriana-lima_5_mask.jpg
# ./data/5cele/adam driver mask/a-photo-of-the-adam-driver_7_mask.jpg
# ./data/5cele/adam driver mask/a-photo-of-the-adam-driver_2_mask.jpg
# ./data/5cele/adam driver mask/a-photo-of-the-adam-driver_5_mask.jpg
# ./data/5cele/adam driver mask/a-photo-of-the-adam-driver_4_mask.jpg
# ./data/5cele/adam driver mask/a-photo-of-the-adam-driver_1_mask.jpg
# ./data/5cele/adam driver mask/a-photo-of-the-adam-driver_3_mask.jpg
# ./data/5cele/adam driver mask/a-photo-of-the-adam-driver_0_mask.jpg
# ./data/5cele/adam driver mask/a-photo-of-the-adam-driver_6_mask.jpg
# ./data/5cele/andrew garfield/a-photo-of-the-andrew-garfield_6.jpg
# ./data/5cele/andrew garfield/a-photo-of-the-andrew-garfield_0.jpg
# ./data/5cele/andrew garfield/a-photo-of-the-andrew-garfield_3.jpg
# ./data/5cele/andrew garfield/a-photo-of-the-andrew-garfield_1.jpg
# ./data/5cele/andrew garfield/a-photo-of-the-andrew-garfield_4.jpg
# ./data/5cele/andrew garfield/a-photo-of-the-andrew-garfield_2.jpg
# ./data/5cele/andrew garfield/a-photo-of-the-andrew-garfield_7.jpg
# ./data/5cele/andrew garfield/a-photo-of-the-andrew-garfield_5.jpg
# ./data/5cele/adriana lima/a-photo-of-the-adriana-lima_1.jpg
# ./data/5cele/adriana lima/a-photo-of-the-adriana-lima_3.jpg
# ./data/5cele/adriana lima/a-photo-of-the-adriana-lima_2.jpg
# ./data/5cele/adriana lima/a-photo-of-the-adriana-lima_5.jpg
# ./data/5cele/adriana lima/a-photo-of-the-adriana-lima_6.jpg
# ./data/5cele/adriana lima/a-photo-of-the-adriana-lima_4.jpg
# ./data/5cele/adriana lima/a-photo-of-the-adriana-lima_0.jpg
# ./data/5cele/adriana lima/a-photo-of-the-adriana-lima_7.jpg
# ./data/5cele/andrew garfield mask mask/a-photo-of-the-andrew-garfield_5_mask_mask.jpg
# ./data/5cele/andrew garfield mask mask/a-photo-of-the-andrew-garfield_3_mask_mask.jpg
# ./data/5cele/andrew garfield mask mask/a-photo-of-the-andrew-garfield_7_mask_mask.jpg
# ./data/5cele/andrew garfield mask mask/a-photo-of-the-andrew-garfield_2_mask_mask.jpg
# ./data/5cele/andrew garfield mask mask/a-photo-of-the-andrew-garfield_4_mask_mask.jpg
# ./data/5cele/andrew garfield mask mask/a-photo-of-the-andrew-garfield_6_mask_mask.jpg
# ./data/5cele/andrew garfield mask mask/a-photo-of-the-andrew-garfield_1_mask_mask.jpg
# ./data/5cele/andrew garfield mask mask/a-photo-of-the-andrew-garfield_0_mask_mask.jpg
# ./data/5cele/amy adams/a-photo-of-the-amy-adams_0.jpg
# ./data/5cele/amy adams/a-photo-of-the-amy-adams_7.jpg
# ./data/5cele/amy adams/a-photo-of-the-amy-adams_3.jpg
# ./data/5cele/amy adams/a-photo-of-the-amy-adams_6.jpg
# ./data/5cele/amy adams/a-photo-of-the-amy-adams_2.jpg
# ./data/5cele/amy adams/a-photo-of-the-amy-adams_1.jpg
# ./data/5cele/amy adams/a-photo-of-the-amy-adams_4.jpg
# ./data/5cele/amy adams/a-photo-of-the-amy-adams_5.jpg
# ./data/5cele/amber heard/a-photo-of-the-amber-heard_4.jpg
# ./data/5cele/amber heard/a-photo-of-the-amber-heard_1.jpg
# ./data/5cele/amber heard/a-photo-of-the-amber-heard_6.jpg
# ./data/5cele/amber heard/a-photo-of-the-amber-heard_0.jpg
# ./data/5cele/amber heard/a-photo-of-the-amber-heard_7.jpg
# ./data/5cele/amber heard/a-photo-of-the-amber-heard_3.jpg
# ./data/5cele/amber heard/a-photo-of-the-amber-heard_2.jpg
# ./data/5cele/amber heard/a-photo-of-the-amber-heard_5.jpg
# ./data/5cele/adam driver/a-photo-of-the-adam-driver_1.jpg
# ./data/5cele/adam driver/a-photo-of-the-adam-driver_7.jpg
# ./data/5cele/adam driver/a-photo-of-the-adam-driver_2.jpg
# ./data/5cele/adam driver/a-photo-of-the-adam-driver_6.jpg
# ./data/5cele/adam driver/a-photo-of-the-adam-driver_5.jpg
# ./data/5cele/adam driver/a-photo-of-the-adam-driver_0.jpg
# ./data/5cele/adam driver/a-photo-of-the-adam-driver_3.jpg
# ./data/5cele/adam driver/a-photo-of-the-adam-driver_4.jpg
# ./data/5cele/amber heard mask/a-photo-of-the-amber-heard_5_mask.jpg
# ./data/5cele/amber heard mask/a-photo-of-the-amber-heard_6_mask.jpg
# ./data/5cele/amber heard mask/a-photo-of-the-amber-heard_0_mask.jpg
# ./data/5cele/amber heard mask/a-photo-of-the-amber-heard_1_mask.jpg
# ./data/5cele/amber heard mask/a-photo-of-the-amber-heard_3_mask.jpg
# ./data/5cele/amber heard mask/a-photo-of-the-amber-heard_7_mask.jpg
# ./data/5cele/amber heard mask/a-photo-of-the-amber-heard_4_mask.jpg
# ./data/5cele/amber heard mask/a-photo-of-the-amber-heard_2_mask.jpg
# ./data/5cele/andrew garfield mask/a-photo-of-the-andrew-garfield_2_mask.jpg
# ./data/5cele/andrew garfield mask/a-photo-of-the-andrew-garfield_4_mask.jpg
# ./data/5cele/andrew garfield mask/a-photo-of-the-andrew-garfield_6_mask.jpg
# ./data/5cele/andrew garfield mask/a-photo-of-the-andrew-garfield_5_mask.jpg
# ./data/5cele/andrew garfield mask/a-photo-of-the-andrew-garfield_7_mask.jpg
# ./data/5cele/andrew garfield mask/a-photo-of-the-andrew-garfield_3_mask.jpg
# ./data/5cele/andrew garfield mask/a-photo-of-the-andrew-garfield_0_mask.jpg
# ./data/5cele/andrew garfield mask/a-photo-of-the-andrew-garfield_1_mask.jpg
# ./data/5cele/amy adams mask/a-photo-of-the-amy-adams_0_mask.jpg
# ./data/5cele/amy adams mask/a-photo-of-the-amy-adams_4_mask.jpg
# ./data/5cele/amy adams mask/a-photo-of-the-amy-adams_5_mask.jpg
# ./data/5cele/amy adams mask/a-photo-of-the-amy-adams_7_mask.jpg
# ./data/5cele/amy adams mask/a-photo-of-the-amy-adams_6_mask.jpg
# ./data/5cele/amy adams mask/a-photo-of-the-amy-adams_2_mask.jpg
# ./data/5cele/amy adams mask/a-photo-of-the-amy-adams_3_mask.jpg
# ./data/5cele/amy adams mask/a-photo-of-the-amy-adams_1_mask.jpg
# CompletedProcess(args=['python', 'data_preparation.py', 'configs/celebrity/erase_cele_5.yaml'], returncode=0)

# %% [markdown]
# ### 3. Finetuning for concept erasure (based on configuration)

# %%
import subprocess, os

subprocess.run(
    ["python", "training.py", config_path],
    env={"CUDA_VISIBLE_DEVICES": str(cuda_num), **dict(**os.environ)}
)
# Out:
# /home/nessessence/anaconda3/envs/mace/lib/python3.10/site-packages/torchvision/datapoints/__init__.py:12: UserWarning: The torchvision.datapoints and torchvision.transforms.v2 namespaces are still Beta. While we do not expect major breaking changes, some APIs may still change according to user feedback. Please submit any feedback you may have in this issue: https://github.com/pytorch/vision/issues/6753, and you can also check out https://github.com/pytorch/vision/issues/7319 to learn more about the APIs that we suspect might involve future changes. You can silence this warning by calling torchvision.disable_beta_transforms_warning().
#   warnings.warn(_BETA_TRANSFORMS_WARNING)
# /home/nessessence/anaconda3/envs/mace/lib/python3.10/site-packages/torchvision/transforms/v2/__init__.py:54: UserWarning: The torchvision.datapoints and torchvision.transforms.v2 namespaces are still Beta. While we do not expect major breaking changes, some APIs may still change according to user feedback. Please submit any feedback you may have in this issue: https://github.com/pytorch/vision/issues/6753, and you can also check out https://github.com/pytorch/vision/issues/7319 to learn more about the APIs that we suspect might involve future changes. You can silence this warning by calling torchvision.disable_beta_transforms_warning().
#   warnings.warn(_BETA_TRANSFORMS_WARNING)
# /home/nessessence/anaconda3/envs/mace/lib/python3.10/site-packages/accelerate/accelerator.py:506: UserWarning: `log_with=tensorboard` was passed but no supported trackers are currently installed.
#   warnings.warn(f"`log_with={log_with}` was passed but no supported trackers are currently installed.")
# 05/11/2025 18:04:24 - INFO - src.cfr_lora_training - Distributed environment: NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: no
#
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# /home/nessessence/anaconda3/envs/mace/lib/python3.10/site-packages/huggingface_hub/file_download.py:1142: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# 100%|██████████| 32/32 [00:00<00:00, 610080.58it/s]
# 100%|██████████| 32/32 [00:03<00:00,  8.64it/s]
# 05/11/2025 18:04:38 - INFO - src.cfr_lora_training - ***** Running training *****
# 05/11/2025 18:04:38 - INFO - src.cfr_lora_training -   Num examples = 8
# 05/11/2025 18:04:38 - INFO - src.cfr_lora_training -   Num batches each epoch = 8
# 05/11/2025 18:04:38 - INFO - src.cfr_lora_training -   Num Epochs = 7
# 05/11/2025 18:04:38 - INFO - src.cfr_lora_training -   Instantaneous batch size per device = 1
# 05/11/2025 18:04:38 - INFO - src.cfr_lora_training -   Total train batch size (w. parallel, distributed & accumulation) = 1
# 05/11/2025 18:04:38 - INFO - src.cfr_lora_training -   Gradient Accumulation steps = 1
# 05/11/2025 18:04:38 - INFO - src.cfr_lora_training -   Total optimization steps = 50
# Steps:   0%|          | 0/50 [00:00<?, ?it/s]
# Using relation-focal importance sampling, which can make training more efficient
#                   and is particularly beneficial in erasing mass concepts with overlapping terms.
# Steps: 100%|██████████| 50/50 [00:16<00:00,  3.10it/s, loss=26.3, lr=0.0001]/home/nessessence/anaconda3/envs/mace/lib/python3.10/site-packages/diffusers/models/attention_processor.py:382: FutureWarning: `set_processor to offload LoRA` is deprecated and will be removed in version 0.26.0. In detail, removing LoRA layers via calling `set_default_attn_processor` is deprecated. Please make sure to call `pipe.unload_lora_weights()` instead.
#   deprecate(
# 05/11/2025 18:04:54 - INFO - src.cfr_lora_training - ***** Running training *****
# 05/11/2025 18:04:54 - INFO - src.cfr_lora_training -   Num examples = 8
# 05/11/2025 18:04:54 - INFO - src.cfr_lora_training -   Num batches each epoch = 8
# 05/11/2025 18:04:54 - INFO - src.cfr_lora_training -   Num Epochs = 7
# 05/11/2025 18:04:54 - INFO - src.cfr_lora_training -   Instantaneous batch size per device = 1
# 05/11/2025 18:04:54 - INFO - src.cfr_lora_training -   Total train batch size (w. parallel, distributed & accumulation) = 1
# 05/11/2025 18:04:54 - INFO - src.cfr_lora_training -   Gradient Accumulation steps = 1
# 05/11/2025 18:04:54 - INFO - src.cfr_lora_training -   Total optimization steps = 50
#
# Steps: 100%|██████████| 50/50 [00:16<00:00,  3.06it/s, loss=26.3, lr=0.0001]
#
# Steps:   0%|          | 0/50 [00:00<?, ?it/s]
# ==================================================================
# Concept 0: A drawing capturing the essence of adam driver
# ==================================================================
# True
# <ConvolutionBackward0 object at 0x7336daf542b0>
# tensor(46.1570, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 46.157047271728516
# True
# <ConvolutionBackward0 object at 0x7336daf55cc0>
# tensor(44.6149, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 44.61488342285156
# True
# <ConvolutionBackward0 object at 0x7336daf55d50>
# tensor(43.9520, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 43.95199966430664
# True
# <ConvolutionBackward0 object at 0x7336daf542b0>
# tensor(36.6268, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 36.62684631347656
# True
# <ConvolutionBackward0 object at 0x7336daf55d20>
# tensor(35.0960, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 35.095985412597656
# True
# <ConvolutionBackward0 object at 0x7336daf55d50>
# tensor(44.4278, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 44.42781448364258
# True
# <ConvolutionBackward0 object at 0x7336daf542b0>
# tensor(22.0796, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 22.07961082458496
# True
# <ConvolutionBackward0 object at 0x7336daf55510>
# tensor(32.5456, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 32.545570373535156
# True
# <ConvolutionBackward0 object at 0x7336daf54e50>
# tensor(31.7750, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 31.774967193603516
# True
# <ConvolutionBackward0 object at 0x7337421d2e00>
# tensor(32.8940, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 32.89399337768555
# True
# <ConvolutionBackward0 object at 0x7337421d2c80>
# tensor(35.3688, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 35.36881637573242
# True
# <ConvolutionBackward0 object at 0x7337421d3fa0>
# tensor(33.9304, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 33.9304313659668
# True
# <ConvolutionBackward0 object at 0x7337421d2e00>
# tensor(20.3001, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 20.300106048583984
# True
# <ConvolutionBackward0 object at 0x7337421d2c80>
# tensor(32.9923, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 32.992252349853516
# True
# <ConvolutionBackward0 object at 0x7337421d3fa0>
# tensor(27.1664, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 27.166412353515625
# True
# <ConvolutionBackward0 object at 0x7337421d3fa0>
# tensor(37.0072, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 37.007240295410156
# True
# <ConvolutionBackward0 object at 0x7336daf0be80>
# tensor(29.8697, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 29.869735717773438
# True
# <ConvolutionBackward0 object at 0x7336daf55d20>
# tensor(31.6682, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 31.668243408203125
# True
# <ConvolutionBackward0 object at 0x7336daf55db0>
# tensor(24.9331, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 24.933095932006836
# True
# <ConvolutionBackward0 object at 0x7336daf55330>
# tensor(28.3044, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 28.304365158081055
# True
# <ConvolutionBackward0 object at 0x7336daf55d20>
# tensor(28.7002, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 28.700237274169922
# True
# <ConvolutionBackward0 object at 0x7336daf55db0>
# tensor(27.8700, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 27.869991302490234
# True
# <ConvolutionBackward0 object at 0x7336daf55330>
# tensor(27.9250, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 27.92501449584961
# True
# <ConvolutionBackward0 object at 0x7336daf55cc0>
# tensor(19.9465, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 19.94652557373047
# True
# <ConvolutionBackward0 object at 0x7336daf0ba00>
# tensor(29.3288, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 29.328752517700195
# True
# <ConvolutionBackward0 object at 0x7336daf0ba00>
# tensor(30.1091, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 30.109052658081055
# True
# <ConvolutionBackward0 object at 0x7336daf55510>
# tensor(26.2053, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 26.205307006835938
# True
# <ConvolutionBackward0 object at 0x7336daf0b850>
# tensor(16.8096, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 16.80963897705078
# True
# <ConvolutionBackward0 object at 0x7336daf09a80>
# tensor(23.1845, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 23.184492111206055
# True
# <ConvolutionBackward0 object at 0x7336daf08880>
# tensor(29.7770, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 29.777000427246094
# True
# <ConvolutionBackward0 object at 0x7336daf0b850>
# tensor(31.0023, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 31.002260208129883
# True
# <ConvolutionBackward0 object at 0x7336daf08640>
# tensor(23.9140, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 23.913951873779297
# True
# <ConvolutionBackward0 object at 0x7336daf55d50>
# tensor(28.0363, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 28.036348342895508
# True
# <ConvolutionBackward0 object at 0x7336daf54520>
# tensor(29.3557, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 29.355703353881836
# True
# <ConvolutionBackward0 object at 0x7336daf545b0>
# tensor(26.9293, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 26.929319381713867
# True
# <ConvolutionBackward0 object at 0x7336daf55d50>
# tensor(16.4448, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 16.444801330566406
# True
# <ConvolutionBackward0 object at 0x7336daf55630>
# tensor(21.0891, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 21.089075088500977
# True
# <ConvolutionBackward0 object at 0x7336daf545b0>
# tensor(25.5121, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 25.512054443359375
# True
# <ConvolutionBackward0 object at 0x7336daf55d50>
# tensor(23.5705, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 23.570520401000977
# True
# <ConvolutionBackward0 object at 0x7336daf55060>
# tensor(22.1933, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 22.19333839416504
# True
# <ConvolutionBackward0 object at 0x7336daf54460>
# tensor(24.9997, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 24.99969482421875
# True
# <ConvolutionBackward0 object at 0x7336daf08460>
# tensor(26.3352, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 26.335193634033203
# True
# <ConvolutionBackward0 object at 0x7336daf0b220>
# tensor(15.9166, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 15.91655445098877
# True
# <ConvolutionBackward0 object at 0x7336daf0ba00>
# tensor(21.8010, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 21.801036834716797
# True
# <ConvolutionBackward0 object at 0x7336daf08460>
# tensor(20.9359, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 20.935867309570312
# True
# <ConvolutionBackward0 object at 0x7336daf0b220>
# tensor(24.8212, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 24.82121467590332
# True
# <ConvolutionBackward0 object at 0x7336daf0ba00>
# tensor(24.5312, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 24.531200408935547
# True
# <ConvolutionBackward0 object at 0x7336daf0be80>
# tensor(23.9817, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 23.9816951751709
# True
# <ConvolutionBackward0 object at 0x7336daf0be80>
# tensor(19.3169, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 19.316926956176758
# True
# <ConvolutionBackward0 object at 0x7336daf54520>
# tensor(26.3308, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 26.330791473388672
# Using relation-focal importance sampling, which can make training more efficient
#                   and is particularly beneficial in erasing mass concepts with overlapping terms.
# Steps:   2%|▏         | 1/50 [00:00<00:19,  2.48it/s]
# Steps:   2%|▏         | 1/50 [00:00<00:19,  2.48it/s, loss=18.1, lr=0.0001]
# Steps:   4%|▍         | 2/50 [00:00<00:16,  2.95it/s, loss=18.1, lr=0.0001]
# Steps:   4%|▍         | 2/50 [00:00<00:16,  2.95it/s, loss=22.2, lr=0.0001]
# Steps:   6%|▌         | 3/50 [00:00<00:14,  3.14it/s, loss=22.2, lr=0.0001]
# Steps:   6%|▌         | 3/50 [00:00<00:14,  3.14it/s, loss=19.8, lr=0.0001]
# Steps:   8%|▊         | 4/50 [00:01<00:14,  3.22it/s, loss=19.8, lr=0.0001]
# Steps:   8%|▊         | 4/50 [00:01<00:14,  3.22it/s, loss=19.2, lr=0.0001]
# Steps:  10%|█         | 5/50 [00:01<00:13,  3.22it/s, loss=19.2, lr=0.0001]
# Steps:  10%|█         | 5/50 [00:01<00:13,  3.22it/s, loss=19.7, lr=0.0001]
# Steps:  12%|█▏        | 6/50 [00:01<00:13,  3.25it/s, loss=19.7, lr=0.0001]
# Steps:  12%|█▏        | 6/50 [00:01<00:13,  3.25it/s, loss=28.5, lr=0.0001]
# Steps:  14%|█▍        | 7/50 [00:02<00:13,  3.30it/s, loss=28.5, lr=0.0001]
# Steps:  14%|█▍        | 7/50 [00:02<00:13,  3.30it/s, loss=20.8, lr=0.0001]
# Steps:  16%|█▌        | 8/50 [00:02<00:12,  3.35it/s, loss=20.8, lr=0.0001]
# Steps:  16%|█▌        | 8/50 [00:02<00:12,  3.35it/s, loss=24.4, lr=0.0001]
# Steps:  18%|█▊        | 9/50 [00:02<00:13,  2.98it/s, loss=24.4, lr=0.0001]
# Steps:  18%|█▊        | 9/50 [00:02<00:13,  2.98it/s, loss=27.5, lr=0.0001]
# Steps:  20%|██        | 10/50 [00:03<00:12,  3.09it/s, loss=27.5, lr=0.0001]
# Steps:  20%|██        | 10/50 [00:03<00:12,  3.09it/s, loss=35.5, lr=0.0001]
# Steps:  22%|██▏       | 11/50 [00:03<00:12,  3.14it/s, loss=35.5, lr=0.0001]
# Steps:  82%|████████▏ | 41/50 [00:12<00:02,  3.00it/s, loss=16.6, lr=0.0001]
# Steps:  82%|████████▏ | 41/50 [00:12<00:02,  3.00it/s, loss=14.9, lr=0.0001]
# Steps:  84%|████████▍ | 42/50 [00:13<00:02,  3.08it/s, loss=14.9, lr=0.0001]
# Steps:  84%|████████▍ | 42/50 [00:13<00:02,  3.08it/s, loss=13.1, lr=0.0001]
# Steps:  86%|████████▌ | 43/50 [00:13<00:02,  3.16it/s, loss=13.1, lr=0.0001]
# Steps:  86%|████████▌ | 43/50 [00:13<00:02,  3.16it/s, loss=14.9, lr=0.0001]
# Steps:  88%|████████▊ | 44/50 [00:13<00:01,  3.21it/s, loss=14.9, lr=0.0001]
# Steps:  88%|████████▊ | 44/50 [00:13<00:01,  3.21it/s, loss=13.8, lr=0.0001]
# Steps:  90%|█████████ | 45/50 [00:14<00:01,  3.23it/s, loss=13.8, lr=0.0001]
# Steps:  90%|█████████ | 45/50 [00:14<00:01,  3.23it/s, loss=13.7, lr=0.0001]
# Steps:  92%|█████████▏| 46/50 [00:14<00:01,  3.23it/s, loss=13.7, lr=0.0001]
# Steps:  92%|█████████▏| 46/50 [00:14<00:01,  3.23it/s, loss=15.8, lr=0.0001]
# Steps:  94%|█████████▍| 47/50 [00:14<00:00,  3.24it/s, loss=15.8, lr=0.0001]
# Steps:  94%|█████████▍| 47/50 [00:14<00:00,  3.24it/s, loss=11.1, lr=0.0001]
# Steps:  96%|█████████▌| 48/50 [00:14<00:00,  3.31it/s, loss=11.1, lr=0.0001]
# Steps:  96%|█████████▌| 48/50 [00:14<00:00,  3.31it/s, loss=14.1, lr=0.0001]
# Steps:  98%|█████████▊| 49/50 [00:15<00:00,  2.93it/s, loss=14.1, lr=0.0001]
# Steps:  98%|█████████▊| 49/50 [00:15<00:00,  2.93it/s, loss=23.7, lr=0.0001]
# Steps: 100%|██████████| 50/50 [00:15<00:00,  2.88it/s, loss=23.7, lr=0.0001]
# Steps: 100%|██████████| 50/50 [00:15<00:00,  2.88it/s, loss=11.3, lr=0.0001]05/11/2025 18:05:10 - INFO - src.cfr_lora_training - ***** Running training *****
# 05/11/2025 18:05:10 - INFO - src.cfr_lora_training -   Num examples = 8
# 05/11/2025 18:05:10 - INFO - src.cfr_lora_training -   Num batches each epoch = 8
# 05/11/2025 18:05:10 - INFO - src.cfr_lora_training -   Num Epochs = 7
# 05/11/2025 18:05:10 - INFO - src.cfr_lora_training -   Instantaneous batch size per device = 1
# 05/11/2025 18:05:10 - INFO - src.cfr_lora_training -   Total train batch size (w. parallel, distributed & accumulation) = 1
# 05/11/2025 18:05:10 - INFO - src.cfr_lora_training -   Gradient Accumulation steps = 1
# 05/11/2025 18:05:10 - INFO - src.cfr_lora_training -   Total optimization steps = 50
# Steps: 100%|██████████| 50/50 [00:15<00:00,  3.13it/s, loss=11.3, lr=0.0001]
# Steps:   0%|          | 0/50 [00:00<?, ?it/s]
# ==================================================================
# Concept 1: A drawing capturing the essence of adriana lima
# ==================================================================
# True
# <ConvolutionBackward0 object at 0x73374417dc30>
# tensor(18.0517, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 18.051727294921875
# True
# <ConvolutionBackward0 object at 0x7336dafd9c00>
# tensor(22.1527, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 22.152664184570312
# True
# <ConvolutionBackward0 object at 0x7336dafd80a0>
# tensor(19.8173, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 19.817298889160156
# True
# <ConvolutionBackward0 object at 0x7336dafd9d80>
# tensor(19.2218, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 19.221782684326172
# True
# <ConvolutionBackward0 object at 0x7336dafd9c90>
# tensor(19.7101, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 19.710100173950195
# True
# <ConvolutionBackward0 object at 0x7336dafd9f60>
# tensor(28.4868, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 28.48680305480957
# True
# <ConvolutionBackward0 object at 0x7336dafd9f00>
# tensor(20.8386, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 20.838590621948242
# True
# <ConvolutionBackward0 object at 0x73374417dc30>
# tensor(24.3895, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 24.38945960998535
# True
# <ConvolutionBackward0 object at 0x7336dafd9d80>
# tensor(27.5451, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 27.545087814331055
# True
# <ConvolutionBackward0 object at 0x7336dafda050>
# tensor(35.4704, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 35.470375061035156
# True
# <ConvolutionBackward0 object at 0x7336dafd9e70>
# tensor(16.0761, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 16.076141357421875
# True
# <ConvolutionBackward0 object at 0x7336dafd9cc0>
# tensor(21.3740, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 21.3740234375
# True
# <ConvolutionBackward0 object at 0x7336dafd8250>
# tensor(20.4895, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 20.489547729492188
# True
# <ConvolutionBackward0 object at 0x7336dafd9ed0>
# tensor(29.8810, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 29.88096809387207
# True
# <ConvolutionBackward0 object at 0x7336dafd9c60>
# tensor(18.6502, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 18.6501522064209
# True
# <ConvolutionBackward0 object at 0x7336daf0a740>
# tensor(17.3776, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 17.377620697021484
# True
# <ConvolutionBackward0 object at 0x7336dafd86d0>
# tensor(16.9245, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 16.924518585205078
# True
# <ConvolutionBackward0 object at 0x7336dafd9e40>
# tensor(22.9360, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 22.93602180480957
# True
# <ConvolutionBackward0 object at 0x7336dafda020>
# tensor(15.3842, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 15.384201049804688
# True
# <ConvolutionBackward0 object at 0x7336dafd9d50>
# tensor(16.1984, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 16.198436737060547
# True
# <ConvolutionBackward0 object at 0x7336dafd8640>
# tensor(14.0126, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 14.012551307678223
# True
# <ConvolutionBackward0 object at 0x7336dafd9ed0>
# tensor(15.9978, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 15.997847557067871
# True
# <ConvolutionBackward0 object at 0x7336dafd9e70>
# tensor(18.1424, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 18.14240264892578
# True
# <ConvolutionBackward0 object at 0x7336dafd9ed0>
# tensor(14.8335, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 14.833475112915039
# True
# <ConvolutionBackward0 object at 0x7336dafd8550>
# tensor(15.0370, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 15.036971092224121
# True
# <ConvolutionBackward0 object at 0x7336dafd81f0>
# tensor(15.6356, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 15.635603904724121
# True
# <ConvolutionBackward0 object at 0x7336dafd84c0>
# tensor(15.9939, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 15.99390983581543
# True
# <ConvolutionBackward0 object at 0x7336dafd8670>
# tensor(19.1037, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 19.103666305541992
# True
# <ConvolutionBackward0 object at 0x7336dafd9ed0>
# tensor(13.3473, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 13.347345352172852
# True
# <ConvolutionBackward0 object at 0x7336dafd9e40>
# tensor(14.1076, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 14.10759162902832
# True
# <ConvolutionBackward0 object at 0x7336dafd8640>
# tensor(16.8181, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 16.818138122558594
# True
# <ConvolutionBackward0 object at 0x7336daf0ba00>
# tensor(14.0925, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 14.092524528503418
# True
# <ConvolutionBackward0 object at 0x7336dafd85b0>
# tensor(16.2515, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 16.251487731933594
# True
# <ConvolutionBackward0 object at 0x7336dafd85e0>
# tensor(13.8719, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 13.871857643127441
# True
# <ConvolutionBackward0 object at 0x7336dafd9ea0>
# tensor(20.4346, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 20.434602737426758
# True
# <ConvolutionBackward0 object at 0x7336dafd8640>
# tensor(14.5555, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 14.555484771728516
# True
# <ConvolutionBackward0 object at 0x7336dafda080>
# tensor(17.9178, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 17.917821884155273
# True
# <ConvolutionBackward0 object at 0x7336dafd9cf0>
# tensor(13.2479, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 13.247949600219727
# True
# <ConvolutionBackward0 object at 0x7336dafd86d0>
# tensor(11.9896, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 11.989612579345703
# True
# <ConvolutionBackward0 object at 0x7336daf0a740>
# tensor(16.5927, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 16.59272003173828
# True
# <ConvolutionBackward0 object at 0x7336dafdbfa0>
# tensor(14.8650, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 14.865033149719238
# True
# <ConvolutionBackward0 object at 0x7336dafd9c00>
# tensor(13.1402, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 13.140162467956543
# True
# <ConvolutionBackward0 object at 0x7336dafd85e0>
# tensor(14.9208, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 14.920760154724121
# True
# <ConvolutionBackward0 object at 0x7336dafd86d0>
# tensor(13.7873, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 13.787280082702637
# True
# <ConvolutionBackward0 object at 0x7336dafd84c0>
# tensor(13.6764, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 13.676361083984375
# True
# <ConvolutionBackward0 object at 0x7336dafd9cc0>
# tensor(15.8428, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 15.842767715454102
# True
# <ConvolutionBackward0 object at 0x7336dafd9f90>
# tensor(11.0878, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 11.087756156921387
# True
# <ConvolutionBackward0 object at 0x7336daf0be80>
# tensor(14.1483, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 14.14829158782959
# True
# <ConvolutionBackward0 object at 0x7336dafd8250>
# tensor(23.7258, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 23.7258358001709
# True
# <ConvolutionBackward0 object at 0x7336dafd80d0>
# tensor(11.2517, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 11.251729965209961
# Using relation-focal importance sampling, which can make training more efficient
#                   and is particularly beneficial in erasing mass concepts with overlapping terms.
# Steps: 100%|██████████| 50/50 [00:15<00:00,  3.08it/s, loss=23.5, lr=0.0001]05/11/2025 18:05:26 - INFO - src.cfr_lora_training - ***** Running training *****
# 05/11/2025 18:05:26 - INFO - src.cfr_lora_training -   Num examples = 8
# 05/11/2025 18:05:26 - INFO - src.cfr_lora_training -   Num batches each epoch = 8
# 05/11/2025 18:05:26 - INFO - src.cfr_lora_training -   Num Epochs = 7
# 05/11/2025 18:05:26 - INFO - src.cfr_lora_training -   Instantaneous batch size per device = 1
# 05/11/2025 18:05:26 - INFO - src.cfr_lora_training -   Total train batch size (w. parallel, distributed & accumulation) = 1
# 05/11/2025 18:05:26 - INFO - src.cfr_lora_training -   Gradient Accumulation steps = 1
# 05/11/2025 18:05:26 - INFO - src.cfr_lora_training -   Total optimization steps = 50
#
# Steps: 100%|██████████| 50/50 [00:15<00:00,  3.13it/s, loss=23.5, lr=0.0001]
#
# Steps:   0%|          | 0/50 [00:00<?, ?it/s]
# ==================================================================
# Concept 2: amber heard during sunset/sunrise
# ==================================================================
# True
# <ConvolutionBackward0 object at 0x7336dafd9ea0>
# tensor(57.5258, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 57.52582550048828
# True
# <ConvolutionBackward0 object at 0x7336dafdaa40>
# tensor(24.6400, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 24.63995361328125
# True
# <ConvolutionBackward0 object at 0x7336dafdaad0>
# tensor(66.1616, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 66.16161346435547
# True
# <ConvolutionBackward0 object at 0x7336dafdacb0>
# tensor(42.8962, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 42.89618682861328
# True
# <ConvolutionBackward0 object at 0x7336dafda9e0>
# tensor(41.5534, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 41.55339431762695
# True
# <ConvolutionBackward0 object at 0x7336dafdad70>
# tensor(43.7385, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 43.738529205322266
# True
# <ConvolutionBackward0 object at 0x7336dafdaef0>
# tensor(48.1000, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 48.10000991821289
# True
# <ConvolutionBackward0 object at 0x7336dafda9b0>
# tensor(40.4611, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 40.4610710144043
# True
# <ConvolutionBackward0 object at 0x7336dafdaf20>
# tensor(46.9288, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 46.92877960205078
# True
# <ConvolutionBackward0 object at 0x7336dafda9e0>
# tensor(35.8351, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 35.83514404296875
# True
# <ConvolutionBackward0 object at 0x7336dafd9d20>
# tensor(30.8430, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 30.84304428100586
# True
# <ConvolutionBackward0 object at 0x7336dafdb010>
# tensor(27.5365, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 27.536535263061523
# True
# <ConvolutionBackward0 object at 0x7336dafd86a0>
# tensor(46.8909, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 46.89094543457031
# True
# <ConvolutionBackward0 object at 0x7336dafdac20>
# tensor(41.7142, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 41.7142448425293
# True
# <ConvolutionBackward0 object at 0x7336dafdaa40>
# tensor(36.5538, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 36.55378723144531
# True
# <ConvolutionBackward0 object at 0x7336dafd9d20>
# tensor(37.5651, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 37.565128326416016
# True
# <ConvolutionBackward0 object at 0x7336dafd91e0>
# tensor(25.1591, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 25.15911293029785
# True
# <ConvolutionBackward0 object at 0x7336dafdb040>
# tensor(39.4991, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 39.49912643432617
# True
# <ConvolutionBackward0 object at 0x7336dafd80d0>
# tensor(31.1043, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 31.104305267333984
# True
# <ConvolutionBackward0 object at 0x7336dafdaa40>
# tensor(43.4620, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 43.462013244628906
# True
# <ConvolutionBackward0 object at 0x7336dafd80a0>
# tensor(45.4803, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 45.48031234741211
# True
# <ConvolutionBackward0 object at 0x7336dafd81f0>
# tensor(32.6755, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 32.67547607421875
# True
# <ConvolutionBackward0 object at 0x7336dafd8a90>
# tensor(36.4954, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 36.4953727722168
# True
# <ConvolutionBackward0 object at 0x7336dafdb370>
# tensor(37.0554, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 37.055355072021484
# True
# <ConvolutionBackward0 object at 0x7336dafdacb0>
# tensor(42.1330, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 42.13304901123047
# True
# <ConvolutionBackward0 object at 0x7336dafdb0d0>
# tensor(32.8627, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 32.862667083740234
# True
# <ConvolutionBackward0 object at 0x7336dafd9c00>
# tensor(38.2305, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 38.23054504394531
# True
# <ConvolutionBackward0 object at 0x7336dafdac20>
# tensor(20.6410, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 20.641014099121094
# True
# <ConvolutionBackward0 object at 0x7336dafda8f0>
# tensor(44.2492, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 44.249210357666016
# True
# <ConvolutionBackward0 object at 0x7336dafd8250>
# tensor(39.8586, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 39.85860061645508
# True
# <ConvolutionBackward0 object at 0x7336dafd9ea0>
# tensor(35.9007, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 35.900657653808594
# True
# <ConvolutionBackward0 object at 0x7336dafd8a90>
# tensor(29.7705, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 29.770545959472656
# True
# <ConvolutionBackward0 object at 0x7336dafd8a00>
# tensor(40.6800, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 40.67995071411133
# True
# <ConvolutionBackward0 object at 0x7336dafda8f0>
# tensor(31.3330, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 31.333049774169922
# True
# <ConvolutionBackward0 object at 0x7336dafdaef0>
# tensor(26.7792, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 26.77920150756836
# True
# <ConvolutionBackward0 object at 0x7336dafd8070>
# tensor(22.3576, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 22.35757064819336
# True
# <ConvolutionBackward0 object at 0x7336dafd8250>
# tensor(40.2301, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 40.23014450073242
# True
# <ConvolutionBackward0 object at 0x7336dafdaad0>
# tensor(30.2146, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 30.214567184448242
# True
# <ConvolutionBackward0 object at 0x7336dafd9c00>
# tensor(31.6427, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 31.642717361450195
# True
# <ConvolutionBackward0 object at 0x7336dafdaef0>
# tensor(29.2316, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 29.231563568115234
# True
# <ConvolutionBackward0 object at 0x7336dafdae30>
# tensor(40.0226, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 40.0225944519043
# True
# <ConvolutionBackward0 object at 0x7336dafd9f60>
# tensor(28.7102, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 28.710174560546875
# True
# <ConvolutionBackward0 object at 0x7336dafd8d30>
# tensor(30.4422, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 30.442222595214844
# True
# <ConvolutionBackward0 object at 0x7336dafd9d20>
# tensor(16.3951, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 16.395050048828125
# True
# <ConvolutionBackward0 object at 0x7336dafdaad0>
# tensor(30.8516, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 30.851585388183594
# True
# <ConvolutionBackward0 object at 0x7336dafd9c00>
# tensor(26.9706, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 26.970569610595703
# True
# <ConvolutionBackward0 object at 0x7336dafd81f0>
# tensor(22.2721, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 22.272064208984375
# True
# <ConvolutionBackward0 object at 0x7336dafdab00>
# tensor(28.6673, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 28.66728973388672
# True
# <ConvolutionBackward0 object at 0x7336dafd91e0>
# tensor(37.8179, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 37.8178825378418
# True
# <ConvolutionBackward0 object at 0x7336dafdafe0>
# tensor(23.5420, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 23.542007446289062
# Using relation-focal importance sampling, which can make training more efficient
#                   and is particularly beneficial in erasing mass concepts with overlapping terms.
# Steps:   2%|▏         | 1/50 [00:00<00:19,  2.49it/s]
# Steps:   2%|▏         | 1/50 [00:00<00:19,  2.49it/s, loss=23.1, lr=0.0001]
# Steps:   4%|▍         | 2/50 [00:00<00:16,  2.89it/s, loss=23.1, lr=0.0001]
# Steps:   4%|▍         | 2/50 [00:00<00:16,  2.89it/s, loss=36.6, lr=0.0001]
# Steps:   6%|▌         | 3/50 [00:01<00:15,  3.07it/s, loss=36.6, lr=0.0001]
# Steps:   6%|▌         | 3/50 [00:01<00:15,  3.07it/s, loss=42.4, lr=0.0001]
# Steps:   8%|▊         | 4/50 [00:01<00:14,  3.18it/s, loss=42.4, lr=0.0001]
# Steps:   8%|▊         | 4/50 [00:01<00:14,  3.18it/s, loss=28.2, lr=0.0001]
# Steps:  10%|█         | 5/50 [00:01<00:13,  3.24it/s, loss=28.2, lr=0.0001]
# Steps:  10%|█         | 5/50 [00:01<00:13,  3.24it/s, loss=23.7, lr=0.0001]
# Steps:  12%|█▏        | 6/50 [00:01<00:13,  3.28it/s, loss=23.7, lr=0.0001]
# Steps:  12%|█▏        | 6/50 [00:01<00:13,  3.28it/s, loss=25.5, lr=0.0001]
# Steps:  14%|█▍        | 7/50 [00:02<00:13,  3.30it/s, loss=25.5, lr=0.0001]
# Steps:  14%|█▍        | 7/50 [00:02<00:13,  3.30it/s, loss=24.5, lr=0.0001]
# Steps:  16%|█▌        | 8/50 [00:02<00:12,  3.35it/s, loss=24.5, lr=0.0001]
# Steps:  16%|█▌        | 8/50 [00:02<00:12,  3.35it/s, loss=24.8, lr=0.0001]
# Steps:  18%|█▊        | 9/50 [00:02<00:13,  2.97it/s, loss=24.8, lr=0.0001]
# Steps:  18%|█▊        | 9/50 [00:02<00:13,  2.97it/s, loss=25.6, lr=0.0001]
# Steps:  20%|██        | 10/50 [00:03<00:12,  3.08it/s, loss=25.6, lr=0.0001]
# Steps:  20%|██        | 10/50 [00:03<00:12,  3.08it/s, loss=19.3, lr=0.0001]
# Steps:  22%|██▏       | 11/50 [00:03<00:12,  3.16it/s, loss=19.3, lr=0.0001]
# Steps:  22%|██▏       | 11/50 [00:03<00:12,  3.16it/s, loss=25.2, lr=0.0001]
# Steps:  82%|████████▏ | 41/50 [00:12<00:03,  2.98it/s, loss=21, lr=0.0001]
# Steps:  84%|████████▍ | 42/50 [00:13<00:02,  3.07it/s, loss=21, lr=0.0001]
# Steps:  84%|████████▍ | 42/50 [00:13<00:02,  3.07it/s, loss=12.5, lr=0.0001]
# Steps:  86%|████████▌ | 43/50 [00:13<00:02,  3.15it/s, loss=12.5, lr=0.0001]
# Steps:  86%|████████▌ | 43/50 [00:13<00:02,  3.15it/s, loss=16.2, lr=0.0001]
# Steps:  88%|████████▊ | 44/50 [00:13<00:01,  3.21it/s, loss=16.2, lr=0.0001]
# Steps:  88%|████████▊ | 44/50 [00:13<00:01,  3.21it/s, loss=15.2, lr=0.0001]
# Steps:  90%|█████████ | 45/50 [00:14<00:01,  3.24it/s, loss=15.2, lr=0.0001]
# Steps:  90%|█████████ | 45/50 [00:14<00:01,  3.24it/s, loss=18.8, lr=0.0001]
# Steps:  92%|█████████▏| 46/50 [00:14<00:01,  3.28it/s, loss=18.8, lr=0.0001]
# Steps:  92%|█████████▏| 46/50 [00:14<00:01,  3.28it/s, loss=17, lr=0.0001]
# Steps:  94%|█████████▍| 47/50 [00:14<00:00,  3.29it/s, loss=17, lr=0.0001]
# Steps:  94%|█████████▍| 47/50 [00:14<00:00,  3.29it/s, loss=15.4, lr=0.0001]
# Steps:  96%|█████████▌| 48/50 [00:15<00:00,  3.35it/s, loss=15.4, lr=0.0001]
# Steps:  96%|█████████▌| 48/50 [00:15<00:00,  3.35it/s, loss=13, lr=0.0001]
# Steps:  98%|█████████▊| 49/50 [00:15<00:00,  2.98it/s, loss=13, lr=0.0001]
# Steps:  98%|█████████▊| 49/50 [00:15<00:00,  2.98it/s, loss=18, lr=0.0001]
# Steps: 100%|██████████| 50/50 [00:15<00:00,  3.08it/s, loss=18, lr=0.0001]
# Steps: 100%|██████████| 50/50 [00:15<00:00,  3.08it/s, loss=16.9, lr=0.0001]05/11/2025 18:05:42 - INFO - src.cfr_lora_training - ***** Running training *****
# 05/11/2025 18:05:42 - INFO - src.cfr_lora_training -   Num examples = 8
# 05/11/2025 18:05:42 - INFO - src.cfr_lora_training -   Num batches each epoch = 8
# 05/11/2025 18:05:42 - INFO - src.cfr_lora_training -   Num Epochs = 7
# 05/11/2025 18:05:42 - INFO - src.cfr_lora_training -   Instantaneous batch size per device = 1
# 05/11/2025 18:05:42 - INFO - src.cfr_lora_training -   Total train batch size (w. parallel, distributed & accumulation) = 1
# 05/11/2025 18:05:42 - INFO - src.cfr_lora_training -   Gradient Accumulation steps = 1
# 05/11/2025 18:05:42 - INFO - src.cfr_lora_training -   Total optimization steps = 50
# Steps: 100%|██████████| 50/50 [00:15<00:00,  3.14it/s, loss=16.9, lr=0.0001]
# Steps:   0%|          | 0/50 [00:00<?, ?it/s]
# ==================================================================
# Concept 3: amy adams in a snapshot
# ==================================================================
# True
# <ConvolutionBackward0 object at 0x7336da5cc8e0>
# tensor(23.0529, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 23.05286979675293
# True
# <ConvolutionBackward0 object at 0x7336da544eb0>
# tensor(36.5767, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 36.57673645019531
# True
# <ConvolutionBackward0 object at 0x7336da5450f0>
# tensor(42.3951, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 42.395118713378906
# True
# <ConvolutionBackward0 object at 0x7336da545150>
# tensor(28.2000, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 28.1999568939209
# True
# <ConvolutionBackward0 object at 0x7336da545330>
# tensor(23.6688, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 23.668825149536133
# True
# <ConvolutionBackward0 object at 0x7336da5450c0>
# tensor(25.4662, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 25.46623420715332
# True
# <ConvolutionBackward0 object at 0x7336da545e40>
# tensor(24.5236, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 24.523635864257812
# True
# <ConvolutionBackward0 object at 0x7336da545120>
# tensor(24.8398, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 24.839820861816406
# True
# <ConvolutionBackward0 object at 0x7336da545270>
# tensor(25.6113, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 25.611303329467773
# True
# <ConvolutionBackward0 object at 0x7336da5454b0>
# tensor(19.3081, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 19.30805206298828
# True
# <ConvolutionBackward0 object at 0x7336da5452a0>
# tensor(25.2282, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 25.22818374633789
# True
# <ConvolutionBackward0 object at 0x7336da547df0>
# tensor(30.1804, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 30.18039894104004
# True
# <ConvolutionBackward0 object at 0x7336da544430>
# tensor(19.7355, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 19.7354679107666
# True
# <ConvolutionBackward0 object at 0x7336da545180>
# tensor(16.5950, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 16.59499740600586
# True
# <ConvolutionBackward0 object at 0x7336da547700>
# tensor(23.1043, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 23.104312896728516
# True
# <ConvolutionBackward0 object at 0x7336da545e40>
# tensor(25.2636, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 25.263561248779297
# True
# <ConvolutionBackward0 object at 0x7336da5453c0>
# tensor(19.9113, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 19.911346435546875
# True
# <ConvolutionBackward0 object at 0x7336da5475e0>
# tensor(30.5288, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 30.528759002685547
# True
# <ConvolutionBackward0 object at 0x7336da5450c0>
# tensor(25.7919, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 25.791933059692383
# True
# <ConvolutionBackward0 object at 0x7336da545270>
# tensor(17.7215, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 17.721500396728516
# True
# <ConvolutionBackward0 object at 0x7336da545e40>
# tensor(18.3730, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 18.372968673706055
# True
# <ConvolutionBackward0 object at 0x7336da545240>
# tensor(19.8057, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 19.80565643310547
# True
# <ConvolutionBackward0 object at 0x7336da5441c0>
# tensor(18.1540, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 18.15395164489746
# True
# <ConvolutionBackward0 object at 0x7336da5450c0>
# tensor(20.9753, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 20.97527503967285
# True
# <ConvolutionBackward0 object at 0x7336da5453c0>
# tensor(20.2413, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 20.24134635925293
# True
# <ConvolutionBackward0 object at 0x7336da5475e0>
# tensor(18.4626, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 18.462575912475586
# True
# <ConvolutionBackward0 object at 0x7336da545120>
# tensor(15.9079, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 15.90785026550293
# True
# <ConvolutionBackward0 object at 0x7336da5441c0>
# tensor(21.3533, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 21.35326385498047
# True
# <ConvolutionBackward0 object at 0x7336da545270>
# tensor(22.3974, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 22.397354125976562
# True
# <ConvolutionBackward0 object at 0x7336da547070>
# tensor(15.8624, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 15.862410545349121
# True
# <ConvolutionBackward0 object at 0x7336da547df0>
# ...
# tensor(22.0927, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 22.092681884765625
# True
# <ConvolutionBackward0 object at 0x7336da5453c0>
# tensor(27.6904, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 27.690397262573242
# True
# <ConvolutionBackward0 object at 0x7336da547490>
# tensor(21.0393, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 21.039264678955078
# True
# <ConvolutionBackward0 object at 0x7336da544430>
# tensor(19.7329, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 19.73286247253418
# True
# <ConvolutionBackward0 object at 0x7336da546f20>
# tensor(23.4476, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 23.447633743286133
# True
# <ConvolutionBackward0 object at 0x7336da5463b0>
# tensor(5.9382, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 5.938201427459717
# True
# <ConvolutionBackward0 object at 0x7336da545150>
# tensor(24.3222, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 24.32215118408203
# True
# <ConvolutionBackward0 object at 0x7336da545000>
# tensor(21.5183, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 21.51826286315918
# True
# <ConvolutionBackward0 object at 0x7336da5463b0>
# tensor(19.2341, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 19.234113693237305
# True
# <ConvolutionBackward0 object at 0x7336da545150>
# tensor(17.2050, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 17.205001831054688
# True
# <ConvolutionBackward0 object at 0x7336da545000>
# tensor(16.8309, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 16.830936431884766
# True
# <ConvolutionBackward0 object at 0x7336da5463b0>
# tensor(23.4971, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 23.497089385986328
# True
# <ConvolutionBackward0 object at 0x7336da545240>
# tensor(17.9883, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 17.98830223083496
# True
# <ConvolutionBackward0 object at 0x7336da547df0>
# tensor(20.0462, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 20.046236038208008
# True
# <ConvolutionBackward0 object at 0x7336da5442b0>
# tensor(5.0674, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 5.067418575286865
# True
# <ConvolutionBackward0 object at 0x7336da545180>
# tensor(17.0867, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 17.086671829223633
# True
# <ConvolutionBackward0 object at 0x7336da547df0>
# tensor(20.4856, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 20.485593795776367
# True
# <ConvolutionBackward0 object at 0x7336da5442b0>
# tensor(19.8595, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 19.8594913482666
# True
# <ConvolutionBackward0 object at 0x7336da545180>
# tensor(16.0514, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 16.0513973236084
# True
# <ConvolutionBackward0 object at 0x7336da547df0>
# tensor(16.9211, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 16.921085357666016
# True
# <ConvolutionBackward0 object at 0x7336da544430>
# tensor(15.2442, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 15.244170188903809
# True
# <ConvolutionBackward0 object at 0x7336da5442b0>
# tensor(17.5263, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 17.526281356811523
# True
# <ConvolutionBackward0 object at 0x7336da545240>
# tensor(20.3085, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 20.30845069885254
# True
# <ConvolutionBackward0 object at 0x7336da546cb0>
# tensor(15.7915, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 15.791498184204102
# True
# <ConvolutionBackward0 object at 0x7336da5442b0>
# tensor(4.7455, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 4.745521068572998
# True
# <ConvolutionBackward0 object at 0x7336da545240>
# tensor(16.7311, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 16.731081008911133
# True
# <ConvolutionBackward0 object at 0x7336da5442b0>
# tensor(15.6345, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 15.634542465209961
# True
# <ConvolutionBackward0 object at 0x7336da545240>
# tensor(16.5192, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 16.519237518310547
# True
# <ConvolutionBackward0 object at 0x7336da5463b0>
# tensor(14.6012, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 14.60120677947998
# True
# <ConvolutionBackward0 object at 0x7336da5448b0>
# tensor(13.8415, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 13.84151840209961
# True
# <ConvolutionBackward0 object at 0x7336da545150>
# tensor(15.1296, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 15.129612922668457
# True
# <ConvolutionBackward0 object at 0x7336da5453c0>
# tensor(15.9485, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 15.948490142822266
# True
# <ConvolutionBackward0 object at 0x7336da5448b0>
# tensor(12.7818, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 12.781835556030273
# True
# <ConvolutionBackward0 object at 0x7336da545150>
# tensor(16.2769, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 16.276918411254883
# True
# <ConvolutionBackward0 object at 0x7336da5453c0>
# tensor(4.7243, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 4.724330902099609
# True
# <ConvolutionBackward0 object at 0x7336da5448b0>
# tensor(17.5725, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 17.572546005249023
# True
# <ConvolutionBackward0 object at 0x7336da547df0>
# tensor(13.0289, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 13.028907775878906
# True
# <ConvolutionBackward0 object at 0x7336da545120>
# tensor(14.5245, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 14.524497985839844
# True
# <ConvolutionBackward0 object at 0x7336da545180>
# tensor(15.0882, device='cuda:0', grad_fn=<AddBackward0>)
# loss: 15.088167190551758
# Loading pipeline components...: 100%|██████████| 7/7 [00:00<00:00, 29.85it/s]
# Steps: 100%|██████████| 50/50 [01:12<00:00,  1.44s/it, loss=15.1, lr=0.0001]
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:03,  1.87it/s]Some weights of the model checkpoint were not used when initializing UNet2DConditionModel:
#  ['down_blocks.0.attentions.0.transformer_blocks.0.attn1.to_k.lora_layer.down.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn1.to_k.lora_layer.up.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn1.to_out.0.lora_layer.down.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn1.to_out.0.lora_layer.up.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn1.to_q.lora_layer.down.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn1.to_q.lora_layer.up.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn1.to_v.lora_layer.down.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn1.to_v.lora_layer.up.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn2.to_k.lora_layer.down.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn2.to_k.lora_layer.up.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn2.to_out.0.lora_layer.down.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn2.to_out.0.lora_layer.up.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn2.to_q.lora_layer.down.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn2.to_q.lora_layer.up.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn2.to_v.lora_layer.down.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn2.to_v.lora_layer.up.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn1.to_k.lora_layer.down.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn1.to_k.lora_layer.up.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn1.to_out.0.lora_layer.down.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn1.to_out.0.lora_layer.up.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn1.to_q.lora_layer.down.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn1.to_q.lora_layer.up.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn1.to_v.lora_layer.down.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn1.to_v.lora_layer.up.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_k.lora_layer.down.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_k.lora_layer.up.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_out.0.lora_layer.down.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_out.0.lora_layer.up.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_q.lora_layer.down.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_q.lora_layer.up.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_v.lora_layer.down.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_v.lora_layer.up.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn1.to_k.lora_layer.down.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn1.to_k.lora_layer.up.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn1.to_out.0.lora_layer.down.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn1.to_out.0.lora_layer.up.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn1.to_q.lora_layer.down.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn1.to_q.lora_layer.up.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn1.to_v.lora_layer.down.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn1.to_v.lora_layer.up.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_k.lora_layer.down.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_k.lora_layer.up.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_out.0.lora_layer.down.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_out.0.lora_layer.up.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_q.lora_layer.down.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_q.lora_layer.up.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_v.lora_layer.down.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_v.lora_layer.up.weight, down_blocks.1 ...
# Loading pipeline components...: 100%|██████████| 7/7 [00:03<00:00,  2.19it/s]
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:03,  1.64it/s]Some weights of the model checkpoint were not used when initializing UNet2DConditionModel:
#  ['down_blocks.0.attentions.0.transformer_blocks.0.attn1.to_k.lora_layer.down.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn1.to_k.lora_layer.up.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn1.to_out.0.lora_layer.down.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn1.to_out.0.lora_layer.up.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn1.to_q.lora_layer.down.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn1.to_q.lora_layer.up.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn1.to_v.lora_layer.down.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn1.to_v.lora_layer.up.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn2.to_k.lora_layer.down.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn2.to_k.lora_layer.up.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn2.to_out.0.lora_layer.down.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn2.to_out.0.lora_layer.up.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn2.to_q.lora_layer.down.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn2.to_q.lora_layer.up.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn2.to_v.lora_layer.down.weight, down_blocks.0.attentions.0.transformer_blocks.0.attn2.to_v.lora_layer.up.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn1.to_k.lora_layer.down.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn1.to_k.lora_layer.up.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn1.to_out.0.lora_layer.down.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn1.to_out.0.lora_layer.up.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn1.to_q.lora_layer.down.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn1.to_q.lora_layer.up.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn1.to_v.lora_layer.down.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn1.to_v.lora_layer.up.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_k.lora_layer.down.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_k.lora_layer.up.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_out.0.lora_layer.down.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_out.0.lora_layer.up.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_q.lora_layer.down.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_q.lora_layer.up.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_v.lora_layer.down.weight, down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_v.lora_layer.up.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn1.to_k.lora_layer.down.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn1.to_k.lora_layer.up.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn1.to_out.0.lora_layer.down.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn1.to_out.0.lora_layer.up.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn1.to_q.lora_layer.down.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn1.to_q.lora_layer.up.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn1.to_v.lora_layer.down.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn1.to_v.lora_layer.up.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_k.lora_layer.down.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_k.lora_layer.up.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_out.0.lora_layer.down.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_out.0.lora_layer.up.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_q.lora_layer.down.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_q.lora_layer.up.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_v.lora_layer.down.weight, down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_v.lora_layer.up.weight, down_blocks.1 ...
# Loading pipeline components...: 100%|██████████| 7/7 [00:03<00:00,  2.13it/s]
# 100%|██████████| 32/32 [00:00<00:00, 550072.66it/s]
# You have saved the LoRA weights using the old format. To convert the old LoRA weights to the new format, you can first load them in a dictionary and then create a new dictionary like the following: `new_state_dict = {f'unet.{module_name}': params for module_name, params in old_state_dict.items()}`.
# You have saved the LoRA weights using the old format. To convert the old LoRA weights to the new format, you can first load them in a dictionary and then create a new dictionary like the following: `new_state_dict = {f'unet.{module_name}': params for module_name, params in old_state_dict.items()}`.
# You have saved the LoRA weights using the old format. To convert the old LoRA weights to the new format, you can first load them in a dictionary and then create a new dictionary like the following: `new_state_dict = {f'unet.{module_name}': params for module_name, params in old_state_dict.items()}`.
# You have saved the LoRA weights using the old format. To convert the old LoRA weights to the new format, you can first load them in a dictionary and then create a new dictionary like the following: `new_state_dict = {f'unet.{module_name}': params for module_name, params in old_state_dict.items()}`.
# You have saved the LoRA weights using the old format. To convert the old LoRA weights to the new format, you can first load them in a dictionary and then create a new dictionary like the following: `new_state_dict = {f'unet.{module_name}': params for module_name, params in old_state_dict.items()}`.
# ============================== Concept 1: adam driver ==============================
# ============================== Concept 2: adriana lima ==============================
# ============================== Concept 3: amber heard ==============================
# ============================== Concept 4: amy adams ==============================
# ============================== Concept 5: andrew garfield ==============================
# 100%|██████████| 32/32 [00:03<00:00,  9.90it/s]
# CompletedProcess(args=['python', 'training.py', 'configs/celebrity/erase_cele_5.yaml'], returncode=0)

# %% [markdown]
# ### 4. Sampling with finetuned model

# %%
import subprocess
import os

cmd = [
    "python", "inference.py",
    "--num_images", "2",
    "--prompt", "a photo of adam-driver",
    "--model_path", "./saved_model/LoRA_fusion_model",
    "--save_path", "./output"
]

subprocess.run(cmd, env={"CUDA_VISIBLE_DEVICES": str(cuda_num), **os.environ})
# Out:
# /home/nessessence/anaconda3/envs/mace/lib/python3.10/site-packages/torchvision/datapoints/__init__.py:12: UserWarning: The torchvision.datapoints and torchvision.transforms.v2 namespaces are still Beta. While we do not expect major breaking changes, some APIs may still change according to user feedback. Please submit any feedback you may have in this issue: https://github.com/pytorch/vision/issues/6753, and you can also check out https://github.com/pytorch/vision/issues/7319 to learn more about the APIs that we suspect might involve future changes. You can silence this warning by calling torchvision.disable_beta_transforms_warning().
#   warnings.warn(_BETA_TRANSFORMS_WARNING)
# /home/nessessence/anaconda3/envs/mace/lib/python3.10/site-packages/torchvision/transforms/v2/__init__.py:54: UserWarning: The torchvision.datapoints and torchvision.transforms.v2 namespaces are still Beta. While we do not expect major breaking changes, some APIs may still change according to user feedback. Please submit any feedback you may have in this issue: https://github.com/pytorch/vision/issues/6753, and you can also check out https://github.com/pytorch/vision/issues/7319 to learn more about the APIs that we suspect might involve future changes. You can silence this warning by calling torchvision.disable_beta_transforms_warning().
#   warnings.warn(_BETA_TRANSFORMS_WARNING)
# Loading pipeline components...: 100%|██████████| 6/6 [00:02<00:00,  2.60it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# Inference using ./saved_model/LoRA_fusion_model...
# 100%|██████████| 30/30 [00:06<00:00,  4.35it/s]
# CompletedProcess(args=['python', 'inference.py', '--num_images', '2', '--prompt', 'a photo of adam-driver', '--model_path', './saved_model/LoRA_fusion_model', '--save_path', './output'], returncode=0)
