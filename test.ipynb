# %%
import torch

# %%
t = torch.load("data_root/logs/c.l4.kv_sceleb5g0U3-V_lr5e-5.ti5e-2_f0.5_b1g4/checkpoint-100/token_embedding.pt")

# %%
t.keys()
# Out:
# dict_keys(['v1', 'v2', 'v3', 'v4', 'v5'])
